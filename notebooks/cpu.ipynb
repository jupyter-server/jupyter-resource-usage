# %%
# from multiprocessing import Pool
# from multiprocessing import cpu_count

def f(x):
    while True:
        x*x

# processes = cpu_count()
# print('utilizing %d cores\n' % processes)
# pool = Pool(processes)
# pool.map(f, range(processes))

f(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <module>
#       6         x*x
#       8 # processes = cpu_count()
#       9 # print('utilizing %d cores\n' % processes)
#      10 # pool = Pool(processes)
#      11 # pool.map(f, range(processes))
# ---> 13 f(1)
#
# Input In [1], in f(x)
#       4 def f(x):
# ----> 5     while True:
#       6         x*x
#
# KeyboardInterrupt:
